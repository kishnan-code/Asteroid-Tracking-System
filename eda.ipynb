# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df =pd.read_csv('astronaut_health_dataset.csv')
df
# Out:
#      heart_rate   hrv  blood_pressure_sys  blood_pressure_dia  \
# 0          80.0  61.8               109.9                60.9
# 1          73.6  56.1               117.8                71.4
# 2          81.5  45.7               108.1                75.9
# 3          90.2  37.2               115.4                98.9
# 4          72.7  53.4                91.6                85.6
# ..          ...   ...                 ...                 ...
# 995        72.2  57.8               121.2                80.3
# 996        93.0  44.7               123.9                59.2
# 997        81.4  34.4               101.4                76.8
# 998        69.3  43.0               125.0                96.4
# 999        80.7  36.1               117.7                83.6
#
#      body_temperature  spo2  respiration_rate  co2_level  oxygen_level  \
# 0               36.57  96.2              12.7      0.679         20.98
# 1               36.98  96.1              14.1      0.422         20.75
# 2               37.01  93.4              13.2      0.671         20.91
# 3               37.24  96.3              14.4      0.577         21.36
# 4               36.32  98.5              15.4      0.671         21.64
# ..                ...   ...               ...        ...           ...
# 995             36.98  97.3              15.1      0.821         21.05
# 996             37.36  99.3              18.3      0.633         21.58
# 997             38.56  94.6              14.4      0.516         21.79
# 998             37.40  97.9              16.0      0.765         20.66
# 999             36.58  94.7              17.2      0.808         21.40
#
#      cabin_temperature  ...  sleep_quality  stress_level  mood_score  \
# 0                 23.1  ...              4             7           9
# 1                 23.6  ...              1             4           4
# 2                 22.7  ...              5             9           5
# 3                 19.1  ...              3             7           1
# 4                 21.8  ...              5             1           2
# ..                 ...  ...            ...           ...         ...
# 995               24.0  ...              4             4           8
# 996               19.0  ...              3             2           7
# 997               20.9  ...              5             2           9
# 998               22.7  ...              4             6           5
# 999               23.0  ...              5             5           6
#
#      exercise_minutes  fatigue_level  water_intake  calories_intake  \
# 0                45.1              9        2780.1           2185.9
# 1                67.3              7        2341.0           2043.4
# 2                32.7              7        2310.5           2708.6
# 3                52.1              5        3120.8           2727.9
# 4                35.1              7        2782.5           2376.1
# ..                ...            ...           ...              ...
# 995              44.4              7        3017.9           2716.4
# 996              34.9              3        2418.3           2284.8
# 997              42.7              4        2246.4           2082.1
# 998              60.4              6        2855.1           2180.5
# 999              39.3              7        2417.5           2245.6
#
#      protein_intake  carbs_intake  health_score
# 0             122.8         381.0            57
# 1             191.9         246.7            58
# 2             188.4         251.6            81
# 3             112.0         352.6            63
# 4             144.0         356.4            62
# ..              ...           ...           ...
# 995            85.5         280.6            96
# 996           119.6         215.5            89
# 997            67.2         219.7            77
# 998           145.0         288.5            76
# 999           138.6         315.7            89
#
# [1000 rows x 24 columns]

# %%
plt.Figure(figsize=(20,16))
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %%
plt.Figure(figsize=(20,16))
sns.histplot(df["health_score"],kde=True , color='blue')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   heart_rate          1000 non-null   float64
#  1   hrv                 1000 non-null   float64
#  2   blood_pressure_sys  1000 non-null   float64
#  3   blood_pressure_dia  1000 non-null   float64
#  4   body_temperature    1000 non-null   float64
#  5   spo2                1000 non-null   float64
#  6   respiration_rate    1000 non-null   float64
#  7   co2_level           1000 non-null   float64
#  8   oxygen_level        1000 non-null   float64
#  9   cabin_temperature   1000 non-null   float64
#  10  radiation           1000 non-null   float64
#  11  microgravity_force  1000 non-null   float64
#  12  reaction_time       1000 non-null   float64
#  13  sleep_hours         1000 non-null   float64
#  14  sleep_quality       1000 non-null   int64
#  15  stress_level        1000 non-null   int64
#  16  mood_score          1000 non-null   int64
#  17  exercise_minutes    1000 non-null   float64
#  18  fatigue_level       1000 non-null   int64
#  19  water_intake        1000 non-null   float64
#  20  calories_intake     1000 non-null   float64
#  21  protein_intake      1000 non-null   float64
#  22  carbs_intake        1000 non-null   float64
#  23  health_score        1000 non-null   int64
# dtypes: float64(19), int64(5)
# memory usage: 187.6 KB

# %%
plt.Figure(figsize=(20,16))
sns.histplot(df["sleep_hours"],kde=True , color='green') 
plt.show()

# %%
plt.Figure(figsize=(20,16))
sns.kdeplot(df["sleep_quality"], color='red', shade=True)
# Out:
# C:\Users\kisha\AppData\Local\Temp\ipykernel_8620\922017998.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["sleep_quality"], color='red', shade=True)
# <Axes: xlabel='sleep_quality', ylabel='Density'>

# %%
df.isnull().sum()
# Out:
# heart_rate            0
# hrv                   0
# blood_pressure_sys    0
# blood_pressure_dia    0
# body_temperature      0
# spo2                  0
# respiration_rate      0
# co2_level             0
# oxygen_level          0
# cabin_temperature     0
# radiation             0
# microgravity_force    0
# reaction_time         0
# sleep_hours           0
# sleep_quality         0
# stress_level          0
# mood_score            0
# exercise_minutes      0
# fatigue_level         0
# water_intake          0
# calories_intake       0
# protein_intake        0
# carbs_intake          0
# health_score          0
# dtype: int64

# %%
# Out:
#         heart_rate          hrv  blood_pressure_sys  blood_pressure_dia  \
# count  1000.000000  1000.000000         1000.000000         1000.000000
# mean     75.193700    45.850500          120.088100           79.812200
# std       9.792083    11.969682           14.752155           10.272227
# min      42.600000     9.700000           74.700000           50.700000
# 25%      68.500000    37.700000          110.300000           72.600000
# 50%      75.250000    45.750000          120.000000           80.000000
# 75%      81.500000    53.725000          129.925000           86.700000
# max     113.500000    83.300000          178.900000          112.400000
#
#        body_temperature         spo2  respiration_rate    co2_level  \
# count       1000.000000  1000.000000       1000.000000  1000.000000
# mean          36.975340    96.907100         15.915900     0.601914
# std            0.496332     2.014616          3.075203     0.104181
# min           35.410000    91.200000          7.900000     0.231000
# 25%           36.660000    95.600000         13.700000     0.530750
# 50%           36.990000    96.900000         15.800000     0.600500
# 75%           37.320000    98.200000         18.100000     0.672000
# max           38.560000   103.200000         26.600000     0.912000
#
#        oxygen_level  cabin_temperature  ...  sleep_quality  stress_level  \
# count   1000.000000        1000.000000  ...     1000.00000   1000.000000
# mean      21.009200          21.981700  ...        3.09900      4.853000
# std        0.505711           1.448639  ...        1.43152      2.546345
# min       19.080000          16.100000  ...        1.00000      1.000000
# 25%       20.680000          21.000000  ...        2.00000      3.000000
# 50%       21.010000          22.000000  ...        3.00000      5.000000
# 75%       21.340000          23.000000  ...        4.00000      7.000000
# max       22.690000          26.200000  ...        5.00000      9.000000
#
#         mood_score  exercise_minutes  fatigue_level  water_intake  \
# count  1000.000000       1000.000000    1000.000000   1000.000000
# mean      5.070000         40.468700       4.969000   2514.374200
# std       2.513049         14.892395       2.602847    390.003895
# min       1.000000         -4.000000       1.000000   1367.000000
# 25%       3.000000         29.900000       3.000000   2253.000000
# 50%       5.000000         40.500000       5.000000   2504.050000
# 75%       7.000000         50.700000       7.000000   2778.975000
# max       9.000000         84.700000       9.000000   3759.600000
#
#        calories_intake  protein_intake  carbs_intake  health_score
# count      1000.000000     1000.000000   1000.000000   1000.000000
# mean       2501.513100      120.631500    301.333700     74.571000
# std         300.641793       25.723324     50.337044     14.322852
# min        1640.300000       47.500000    152.600000     50.000000
# 25%        2296.150000      103.150000    270.075000     62.000000
# 50%        2490.000000      120.050000    301.950000     75.000000
# 75%        2703.475000      137.900000    336.100000     87.000000
# max        3513.000000      205.200000    490.300000     99.000000
#
# [8 rows x 24 columns]
